# %% [markdown]
# Situation:  A manufacturing process is producing product that is not to spec.  There isn't any obvious reasons so we are looking to determine which features are the main influencers of the target specs (Target 1 and Target 2).  The difference in the two targets is that this spec is tested twice in the process, Target 1 is the later testing and the method is more reliable.  Target 2 is earlier in the process and unable to be tested the same way as Target 1, and has more variation.

# %%
#downloading libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# There are 3 main process that collect data but the data collection doesn't merge well.  First we will import the data and combine it, preparing it for analysis.  Loading the first process data into a dataframe.

# %%
df1 = pd.read_csv('Process 1.csv')
df1.head()
# Out:
#    P1 Batch_Number Process 1 START_TIME Process 1 END_TIME    P1 Feature 1  \
# 0           835548      6/16/2023 16:50    6/16/2023 16:50             NaN
# 1           570976     10/24/2022 16:04   10/25/2022 15:26             NaN
# 2           570958     10/22/2022 12:30   10/24/2022 16:04  Raw Material 1
# 3           570676     10/25/2022 21:37   10/25/2022 23:38             NaN
# 4           499819      9/13/2023 21:37     9/14/2023 0:09             NaN
#
#    P1 Feature 2  P1 Feature 3  P1 Feature 4 P1 Feature 5
# 0           NaN           NaN           NaN          NaN
# 1           NaN           NaN       21500.0       GRD501
# 2          16.2      570958.0       21481.0       GRD501
# 3           NaN           NaN       21514.0          NaN
# 4           NaN           NaN     2330487.0          NaN

# %%
df1.shape
# Out:
# (1612, 8)

# %% [markdown]
# Loading the second process data into a dataframe

# %%
df2 = pd.read_csv('Process 2.csv')
df2.head()
# Out:
#    P2 Batch_Number  P2 Batch_Child  P2 Batch_Parent     P2 START_TIME  \
# 0            13272         59829.0          22169.0  11/30/2020 13:30
# 1            13267         59811.0          22169.0   11/30/2020 4:12
# 2            13263         59811.0          22169.0  11/29/2020 21:39
# 3            13259         59811.0          22169.0  11/29/2020 15:37
# 4            13254         59805.0          22167.0   11/29/2020 9:31
#
#         P2 END_TIME  P2 Feature 1  P2 Feature 2  P2 Feature 3  Target 2  \
# 0   12/3/2020 13:15          99.2          58.4           NaN       NaN
# 1   12/1/2020 11:55           NaN           NaN          0.68       3.0
# 2  11/30/2020 19:26           NaN           NaN          0.84       3.0
# 3  11/30/2020 19:07           NaN           NaN          0.96       1.0
# 4   11/30/2020 8:05           NaN           NaN          0.84       3.0
#
#    P2 Feature 4  P2 Feature 5 P2 Feature 6  P2 Feature 7  P2 Feature 8  \
# 0           NaN           NaN         R804      6678.383      1.722872
# 1           7.0           NaN         R804      8074.866      1.781492
# 2           6.8           NaN         R804      8907.036      1.783088
# 3           6.8           NaN         R804      8922.198      1.781203
# 4           6.8           NaN         R804      8992.614      1.780991
#
#    P2 Feature 9  P2 Feature 10  P2 Feature 11  P2 Feature 12
# 0      1.169222       0.655117           11.0            581
# 1      1.189442       0.656123           14.0            581
# 2      1.190846       0.656202           12.0            581
# 3      1.188748       0.656282           14.0            581
# 4      1.190788       0.656358           13.0            581

# %%
df2.shape
# Out:
# (660, 18)

# %% [markdown]
# merging the dataframes by the batch numbers

# %%
df4=pd.merge(df2,df1, left_on='P2 Batch_Parent', right_on='P1 Batch_Number')
df4.head()
# Out:
#    P2 Batch_Number  P2 Batch_Child  P2 Batch_Parent   P2 START_TIME  \
# 0            14081         60513.0          22177.0   2/4/2021 2:43
# 1            14076         60513.0          22177.0  2/3/2021 21:00
# 2            14071         60506.0          22177.0  2/3/2021 15:36
# 3            14068         60506.0          22177.0   2/3/2021 9:49
# 4            14064         60503.0          22177.0   2/3/2021 3:09
#
#       P2 END_TIME  P2 Feature 1  P2 Feature 2  P2 Feature 3  Target 2  \
# 0   2/5/2021 7:22         98.75          50.4           NaN       3.0
# 1  2/4/2021 23:55           NaN           NaN           NaN       2.0
# 2  2/4/2021 23:36           NaN           NaN           NaN       3.0
# 3   2/4/2021 4:54           NaN           NaN           NaN       2.0
# 4   2/4/2021 4:44         97.61          54.1           NaN       1.0
#
#    P2 Feature 4  ...  P2 Feature 11 P2 Feature 12  P1 Batch_Number  \
# 0           6.7  ...           50.0           597            22177
# 1           6.6  ...           11.0           597            22177
# 2           6.7  ...           11.0           597            22177
# 3           6.5  ...           60.0           597            22177
# 4           6.5  ...           34.0           597            22177
#
#    Process 1 START_TIME  Process 1 END_TIME    P1 Feature 1  P1 Feature 2  \
# 0        2/1/2021 18:35      2/4/2021 11:03  Raw Material 7          9.37
# 1        2/1/2021 18:35      2/4/2021 11:03  Raw Material 7          9.37
# 2        2/1/2021 18:35      2/4/2021 11:03  Raw Material 7          9.37
# 3        2/1/2021 18:35      2/4/2021 11:03  Raw Material 7          9.37
# 4        2/1/2021 18:35      2/4/2021 11:03  Raw Material 7          9.37
#
#    P1 Feature 3  P1 Feature 4 P1 Feature 5
# 0       22177.0       14058.0          NaN
# 1       22177.0       14058.0          NaN
# 2       22177.0       14058.0          NaN
# 3       22177.0       14058.0          NaN
# 4       22177.0       14058.0          NaN
#
# [5 rows x 26 columns]

# %%
df4.shape
# Out:
# (494, 26)

# %% [markdown]
# Notice that the all of the columns from Process 1 data were added teh Process 2 data, but the rows from Process 1 data that did not contain a batch number that matched Process 2 were dropped, reducing the total row count to 494.  Now adding the data from the third process into a new dataframe:

# %%
df3 = pd.read_csv('Process 3.csv')
df3.head()
# Out:
#    P3 Batch_Number P3 Batch_Child P3 Batch_Parent    P3 START_TIME  \
# 0            68161     2464505893           68160   10/7/2023 0:17
# 1            68160          68160      2464446327  10/6/2023 10:36
# 2            68160          68160           68160  10/6/2023 10:33
# 3            68136          68136      2464213623  10/5/2023 10:59
# 4            68136          68136           68136  10/5/2023 10:56
#
#        P3 END_TIME  P3 Feature 1  P3 Feature 2  P3 Feature 3  P3 Feature 4  \
# 0              NaN           NaN         98.65         78.45          48.2
# 1   10/7/2023 0:28           NaN           NaN           NaN           NaN
# 2   10/7/2023 0:10           NaN           NaN           NaN           NaN
# 3  10/5/2023 22:01           NaN         98.50         84.20          54.5
# 4  10/5/2023 19:27           NaN           NaN           NaN           NaN
#
#    P3 Feature 5  P3 Feature 6  Target 1  P3 Feature 7
# 0           NaN          20.0       3.6           2.1
# 1           NaN           NaN       NaN           NaN
# 2           NaN           NaN       NaN           NaN
# 3           NaN          22.0       3.8           2.8
# 4           NaN           NaN       NaN           NaN

# %%
df3.shape
# Out:
# (360, 13)

# %% [markdown]
# Now adding that Process 3 data to the merged dataframe of the other two processes:

# %%
df5=pd.merge(df4,df3, left_on='P2 Batch_Child', right_on='P3 Batch_Number')
df5.shape
# Out:
# (464, 39)

# %% [markdown]
# The new shape of the newly merged dataframe (df5) shows we've added all of the colunns from Process 3 (df3), and because not all of the data had a corresponding batch number in the process 3 data (df3), we've lost more rows of data.

# %%
df5.head()
# Out:
#    P2 Batch_Number  P2 Batch_Child  P2 Batch_Parent   P2 START_TIME  \
# 0            14081         60513.0          22177.0   2/4/2021 2:43
# 1            14076         60513.0          22177.0  2/3/2021 21:00
# 2            14071         60506.0          22177.0  2/3/2021 15:36
# 3            14068         60506.0          22177.0   2/3/2021 9:49
# 4            14064         60503.0          22177.0   2/3/2021 3:09
#
#       P2 END_TIME  P2 Feature 1  P2 Feature 2  P2 Feature 3  Target 2  \
# 0   2/5/2021 7:22         98.75          50.4           NaN       3.0
# 1  2/4/2021 23:55           NaN           NaN           NaN       2.0
# 2  2/4/2021 23:36           NaN           NaN           NaN       3.0
# 3   2/4/2021 4:54           NaN           NaN           NaN       2.0
# 4   2/4/2021 4:44         97.61          54.1           NaN       1.0
#
#    P2 Feature 4  ...   P3 START_TIME     P3 END_TIME  P3 Feature 1  \
# 0           6.7  ...  2/4/2021 22:02   2/5/2021 8:15           1.0
# 1           6.6  ...  2/4/2021 22:02   2/5/2021 8:15           1.0
# 2           6.7  ...   2/4/2021 4:40  2/4/2021 10:02           NaN
# 3           6.5  ...   2/4/2021 4:40  2/4/2021 10:02           NaN
# 4           6.5  ...  2/3/2021 21:10  2/4/2021 16:25           1.0
#
#    P3 Feature 2  P3 Feature 3  P3 Feature 4  P3 Feature 5  P3 Feature 6  \
# 0         98.70           NaN          51.0         100.0          15.0
# 1         98.70           NaN          51.0         100.0          15.0
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4         98.65           NaN          56.2          99.9          14.0
#
#    Target 1 P3 Feature 7
# 0       NaN          0.9
# 1       NaN          0.9
# 2       NaN          NaN
# 3       NaN          NaN
# 4       NaN          0.8
#
# [5 rows x 39 columns]

# %% [markdown]
# In the data sample above we can see that our dataset has null values in Target 1 column.  We need to remove those to eliminate the batches that did not test for it.

# %%
df6=df5.dropna(subset=['Target 1'])
df6.head()
# Out:
#      P2 Batch_Number  P2 Batch_Child  P2 Batch_Parent    P2 START_TIME  \
# 369          2340190         67350.0          40359.0   6/29/2023 9:24
# 370          2330365         67350.0          40358.0   6/29/2023 3:52
# 371          2330366         67350.0          40299.0  6/29/2023 11:27
# 372          2340189         67347.0          40358.0   6/29/2023 2:56
# 373          2340188         67347.0          40358.0  6/28/2023 20:29
#
#          P2 END_TIME  P2 Feature 1  P2 Feature 2  P2 Feature 3  Target 2  \
# 369  6/30/2023 22:28           NaN           NaN          0.59       4.0
# 370  6/30/2023 22:25         96.95          39.5          0.24       4.0
# 371    7/1/2023 8:28           NaN           NaN          0.70       3.0
# 372  6/30/2023 21:39           NaN           NaN          0.34       4.0
# 373  6/30/2023 12:13           NaN           NaN          0.75       4.0
#
#      P2 Feature 4  ...    P3 START_TIME    P3 END_TIME  P3 Feature 1  \
# 369           6.3  ...  6/30/2023 21:14  7/2/2023 2:58           1.0
# 370           6.0  ...  6/30/2023 21:14  7/2/2023 2:58           1.0
# 371           4.4  ...  6/30/2023 21:14  7/2/2023 2:58           1.0
# 372           6.5  ...  6/30/2023 11:28  7/1/2023 7:06           1.0
# 373           6.3  ...  6/30/2023 11:28  7/1/2023 7:06           1.0
#
#      P3 Feature 2  P3 Feature 3  P3 Feature 4  P3 Feature 5  P3 Feature 6  \
# 369          97.2           NaN          42.5         100.0          16.0
# 370          97.2           NaN          42.5         100.0          16.0
# 371          97.2           NaN          42.5         100.0          16.0
# 372          98.5           NaN          40.5         100.0          18.0
# 373          98.5           NaN          40.5         100.0          18.0
#
#      Target 1 P3 Feature 7
# 369       5.0          1.2
# 370       5.0          1.2
# 371       5.0          1.2
# 372       4.3          1.7
# 373       4.3          1.7
#
# [5 rows x 39 columns]

# %%
df6.shape
# Out:
# (93, 39)

# %% [markdown]
# This reduces our data down quite a bit from 464 batches to 93.  Not all batches end up going to a final product that requires our target to hit a certain spec, and therefore they arent tested for it and we can disregard them in this analysis.  Lets check our data for any columns that have zero data in them (Count shows as "0", as that can affect the results.

# %%
df6.describe()
# Out:
#        P2 Batch_Number  P2 Batch_Child  P2 Batch_Parent  P2 Feature 1  \
# count     9.300000e+01       93.000000        93.000000     45.000000
# mean      2.334965e+06    67627.623656     40263.365591     99.250444
# std       4.938609e+03      315.906250      2087.325805      0.665825
# min       2.330341e+06    67250.000000     22679.000000     96.950000
# 25%       2.330442e+06    67325.000000     40346.000000     98.800000
# 50%       2.330465e+06    67894.000000     40371.000000     99.550000
# 75%       2.340187e+06    67931.000000     40374.000000     99.750000
# max       2.340367e+06    67973.000000     49794.000000    100.000000
#
#        P2 Feature 2  P2 Feature 3   Target 2  P2 Feature 4  P2 Feature 5  \
# count     45.000000     72.000000  89.000000     89.000000      7.000000
# mean      50.320000      0.635000   3.112360      6.357303      8.171429
# std        6.300382      0.274908   0.845284      0.335372      0.811817
# min       36.200000      0.030000   2.000000      4.400000      7.400000
# 25%       45.500000      0.467500   3.000000      6.300000      7.400000
# 50%       50.300000      0.600000   3.000000      6.400000      8.000000
# 75%       54.800000      0.792500   4.000000      6.500000      8.900000
# max       64.400000      1.570000   6.000000      7.000000      9.200000
#
#        P2 Feature 7  ...  P1 Feature 4  P3 Batch_Number  P3 Feature 1  \
# count     93.000000  ...  9.300000e+01        93.000000          61.0
# mean    8494.131226  ...  2.336651e+06     67627.623656           1.0
# std      454.255661  ...  4.747718e+03       315.906250           0.0
# min     6754.292000  ...  2.330341e+06     67250.000000           1.0
# 25%     8309.752000  ...  2.330455e+06     67325.000000           1.0
# 50%     8463.582000  ...  2.340174e+06     67894.000000           1.0
# 75%     8905.967000  ...  2.340185e+06     67931.000000           1.0
# max     9462.431000  ...  2.340361e+06     67973.000000           1.0
#
#        P3 Feature 2  P3 Feature 3  P3 Feature 4  P3 Feature 5  P3 Feature 6  \
# count     93.000000           0.0     93.000000     93.000000     93.000000
# mean      98.972043           NaN     50.075269     99.959677     19.924731
# std        1.085339           NaN      6.295386      0.061352      2.927518
# min       90.850000           NaN     39.000000     99.800000     14.000000
# 25%       98.500000           NaN     44.500000     99.900000     18.000000
# 50%       99.150000           NaN     51.400000    100.000000     20.000000
# 75%       99.600000           NaN     54.700000    100.000000     22.000000
# max       99.850000           NaN     63.300000    100.000000     27.000000
#
#         Target 1  P3 Feature 7
# count  93.000000     93.000000
# mean    3.744086      1.429032
# std     0.418969      0.357096
# min     3.000000      0.900000
# 25%     3.600000      1.200000
# 50%     3.800000      1.400000
# 75%     3.900000      1.500000
# max     5.500000      3.200000
#
# [8 rows x 28 columns]

# %% [markdown]
# There is at least one shown, lets remove all columns that contain no data:

# %%
df6=df6.dropna(axis=1, how='all')

# %%
df6.dtypes
# Out:
# P2 Batch_Number           int64
# P2 Batch_Child          float64
# P2 Batch_Parent         float64
# P2 START_TIME            object
# P2 END_TIME              object
# P2 Feature 1            float64
# P2 Feature 2            float64
# P2 Feature 3            float64
# Target 2                float64
# P2 Feature 4            float64
# P2 Feature 5            float64
# P2 Feature 6             object
# P2 Feature 7            float64
# P2 Feature 8            float64
# P2 Feature 9            float64
# P2 Feature 10           float64
# P2 Feature 11           float64
# P2 Feature 12             int64
# P1 Batch_Number           int64
# Process 1 START_TIME     object
# Process 1 END_TIME       object
# P1 Feature 1             object
# P1 Feature 2            float64
# P1 Feature 3            float64
# P1 Feature 4            float64
# P3 Batch_Number           int64
# P3 Batch_Child           object
# P3 Batch_Parent          object
# P3 START_TIME            object
# P3 END_TIME              object
# P3 Feature 1            float64
# P3 Feature 2            float64
# P3 Feature 4            float64
# P3 Feature 5            float64
# P3 Feature 6            float64
# Target 1                float64
# P3 Feature 7            float64
# dtype: object

# %% [markdown]
# Removing columns that we used to connect the data but don't inform our analysis like batch numbers.  Converting start/end times from string objects to a date/time format is also needed in order to calculate a duration.

# %%
#convert string objects to date/time format

# %%
#converting into datetime format
#Process 1
#df6['P1 End Year']=pd.to_datetime(df6['Process 1 END_TIME']).dt.year
#df6['P1 End Month']=pd.to_datetime(df6['Process 1 END_TIME']).dt.month
#df6['P1 End Day']=pd.to_datetime(df6['Process 1 END_TIME']).dt.day
#df6['P1 End Time']=pd.to_datetime(df6['Process 1 END_TIME']).dt.time

#df6['P1 Start Year']=pd.to_datetime(df6['Process 1 START_TIME']).dt.year
#df6['P1 Start Month']=pd.to_datetime(df6['Process 1 START_TIME']).dt.month
#df6['P1 Start Day']=pd.to_datetime(df6['Process 1 START_TIME']).dt.day
#df6['P1 Start Time']=pd.to_datetime(df6['Process 1 START_TIME']).dt.time

#Process 2
#df6['P2 End Year']=pd.to_datetime(df6['P2 END_TIME']).dt.year
#df6['P2 End Month']=pd.to_datetime(df6['P2 END_TIME']).dt.month
#df6['P2 End Day']=pd.to_datetime(df6['P2 END_TIME']).dt.day
#df6['P2 End Time']=pd.to_datetime(df6['P2 END_TIME']).dt.time

#df6['P2 Start Year']=pd.to_datetime(df6['P2 START_TIME']).dt.year
#df6['P2 Start Month']=pd.to_datetime(df6['P2 START_TIME']).dt.month
#df6['P2 Start Day']=pd.to_datetime(df6['P2 START_TIME']).dt.day
#df6['P2 Start Time']=pd.to_datetime(df6['P2 START_TIME']).dt.time

#Process 3
#df6['P3 End Year']=pd.to_datetime(df6['P3 END_TIME']).dt.year
#df6['P3 End Month']=pd.to_datetime(df6['P3 END_TIME']).dt.month
#df6['P3 End Day']=pd.to_datetime(df6['P3 END_TIME']).dt.day
#df6['P3 End Time']=pd.to_datetime(df6['P3 END_TIME']).dt.time

#df6['P3 Start Year']=pd.to_datetime(df6['P3 START_TIME']).dt.year
#df6['P3 Start Month']=pd.to_datetime(df6['P3 START_TIME']).dt.month
#df6['P3 Start Day']=pd.to_datetime(df6['P3 START_TIME']).dt.day
#df6['P3 Start Time']=pd.to_datetime(df6['P3 START_TIME']).dt.time

# %%
#adding P2 Duration column: 
#df6['P2 duration']=df6['P2 END_TIME']-df6['P2 START_TIME']

# %%
#adding P3 Duration column: 
#df6['P3 duration']=df6['P3 END_TIME']-df6['P3 START_TIME']

# %%
#removing batch numbers and start/end times
df7=df6.drop(["P2 Batch_Number","P2 Batch_Child","P2 Batch_Parent","P2 START_TIME","P2 END_TIME","P1 Batch_Number","Process 1 START_TIME","Process 1 END_TIME","P3 Batch_Number","P3 Batch_Child","P3 Batch_Parent","P3 START_TIME","P3 END_TIME"],1)
df7.head(1)
# Out:
#      P2 Feature 1  P2 Feature 2  P2 Feature 3  Target 2  P2 Feature 4  \
# 369           NaN           NaN          0.59       4.0           6.3
#
#      P2 Feature 5 P2 Feature 6  P2 Feature 7  P2 Feature 8  P2 Feature 9  ...  \
# 369           NaN         R804      8557.103      1.700671      1.170253  ...
#
#      P1 Feature 2  P1 Feature 3  P1 Feature 4 P3 Feature 1  P3 Feature 2  \
# 369          9.26       40359.0     2340189.0          1.0          97.2
#
#      P3 Feature 4  P3 Feature 5  P3 Feature 6  Target 1  P3 Feature 7
# 369          42.5         100.0          16.0       5.0           1.2
#
# [1 rows x 24 columns]

# %% [markdown]
# Now that all of our data has target values, and has continous data throughout the 3 stage manufacturing process, all columns contain data, and we removed the unnecessary linking columns, we can begin to look for insights.  We'll start out with a correlation heat map:

# %%
corr = df7.corr(numeric_only = True)
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values)
# Out:
# <Axes: >

# %% [markdown]
# The light spots show a higher correlation, so if we look at the rows/columns associated with the Target 1,we see that there are higher correlations with P2 Features 5 and 10.  Lets find the actual correlations for all of the features compared to Target 1 to make it more clear

# %%
Target1corr=df7.corrwith(df7['Target 1'],numeric_only = True)
Target1corr.sort_values(ascending=[False])
# Out:
# Target 1         1.000000
# P2 Feature 5     0.779874
# P2 Feature 10    0.570314
# Target 2         0.396232
# P1 Feature 4     0.310293
# P3 Feature 5     0.226370
# P3 Feature 7     0.163536
# P1 Feature 2     0.030038
# P3 Feature 6    -0.054868
# P1 Feature 3    -0.066201
# P2 Feature 3    -0.083995
# P2 Feature 11   -0.084064
# P2 Feature 7    -0.246009
# P2 Feature 4    -0.337971
# P2 Feature 2    -0.372348
# P2 Feature 9    -0.384305
# P3 Feature 4    -0.403651
# P2 Feature 8    -0.439915
# P2 Feature 12   -0.484170
# P2 Feature 1    -0.599338
# P3 Feature 2    -0.728354
# P3 Feature 1          NaN
# dtype: float64

# %% [markdown]
# Here we see that the features with the highest positive correlation are P2 Features 5 and 10.  The items with the largest negative correlation are P2 Feature 1 and P3 feature 2.  Below are the detailed plots of those features to better see the correlation.

# %%
#positive correlation (.78)
plot=sns.jointplot(x="Target 1", y='P2 Feature 5', data=df7)

# %%
#positive correlation (.57)
plotP2F1=sns.jointplot(x="Target 1", y='P2 Feature 10', data=df7)

# %%
#negative correlation (-.60)
plotP2F1=sns.jointplot(x="Target 1", y='P2 Feature 1', data=df7)

# %%
#negative correlation (-.73)
plotP3F2=sns.jointplot(x="Target 1", y='P3 Feature 2', data=df7)

# %% [markdown]
# So from this correlation analysis we see that the first two features have a pretty strong positive relationship with the Target (when Target 1 is high, they are high), while the second two have a pretty strong negative or opposite relationship (when Target 1 is high, they are low).  Lets further investigate with a regression model analysis.

# %% [markdown]
# ## Regression Model with Pycaret

# %%
from pycaret.regression import *

# %% [markdown]
# Now we've imported the pycaret library and setup the model to normalize the data.  This allows the scale of the measurements to not affect the analysis or weight it incorrectly in the direction of the larger numbers.  With larger numbers the difference can be larger and therefore incorrectly be correlated with a larger affect.  Normalizing puts all the data on an equal scale and allows the smaller numbers to be equally analyized.

# %%
model = setup(
    data = df7,
    target = 'Target 1',
    normalize=True)
# Out:
# <style type="text/css">
# #T_d99a9_row11_col1, #T_d99a9_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d99a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d99a9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d99a9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d99a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d99a9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d99a9_row0_col1" class="data row0 col1" >4386</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d99a9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d99a9_row1_col1" class="data row1 col1" >Target 1</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d99a9_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d99a9_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d99a9_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_d99a9_row3_col1" class="data row3 col1" >(93, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d99a9_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_d99a9_row4_col1" class="data row4 col1" >(93, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d99a9_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_d99a9_row5_col1" class="data row5 col1" >(65, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d99a9_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_d99a9_row6_col1" class="data row6 col1" >(28, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d99a9_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_d99a9_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d99a9_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_d99a9_row8_col1" class="data row8 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d99a9_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_d99a9_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d99a9_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_d99a9_row10_col1" class="data row10 col1" >97.8%</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d99a9_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_d99a9_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d99a9_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_d99a9_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d99a9_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_d99a9_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d99a9_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_d99a9_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d99a9_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_d99a9_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d99a9_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_d99a9_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d99a9_row17_col0" class="data row17 col0" >Normalize</td>
#       <td id="T_d99a9_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d99a9_row18_col0" class="data row18 col0" >Normalize method</td>
#       <td id="T_d99a9_row18_col1" class="data row18 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d99a9_row19_col0" class="data row19 col0" >Fold Generator</td>
#       <td id="T_d99a9_row19_col1" class="data row19 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d99a9_row20_col0" class="data row20 col0" >Fold Number</td>
#       <td id="T_d99a9_row20_col1" class="data row20 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d99a9_row21_col0" class="data row21 col0" >CPU Jobs</td>
#       <td id="T_d99a9_row21_col1" class="data row21 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_d99a9_row22_col0" class="data row22 col0" >Use GPU</td>
#       <td id="T_d99a9_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_d99a9_row23_col0" class="data row23 col0" >Log Experiment</td>
#       <td id="T_d99a9_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_d99a9_row24_col0" class="data row24 col0" >Experiment Name</td>
#       <td id="T_d99a9_row24_col1" class="data row24 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d99a9_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_d99a9_row25_col0" class="data row25 col0" >USI</td>
#       <td id="T_d99a9_row25_col1" class="data row25 col1" >59f9</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We have elected to do a Regression Model because it is better at both predicting trends and determining finding major influencers of a variable.  Now we will compare the different models with our data and see which one has the best fit.  This is done through  running each model and then calculating both the Coefficient of determination and multiple types of error (Mean Absolute Error, Mean Squared Error, Root Mean Squared Error, Root Mean Squared Logarithmic Error, and Mean absolute percentage error).  The best values of each are highlighted and the model with the most highlighted values is considered the best fit.

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_be53a th {
#   text-align: left;
# }
# #T_be53a_row0_col0, #T_be53a_row1_col0, #T_be53a_row1_col1, #T_be53a_row1_col2, #T_be53a_row1_col3, #T_be53a_row1_col4, #T_be53a_row1_col5, #T_be53a_row1_col6, #T_be53a_row2_col0, #T_be53a_row2_col1, #T_be53a_row2_col2, #T_be53a_row2_col3, #T_be53a_row2_col4, #T_be53a_row2_col5, #T_be53a_row2_col6, #T_be53a_row3_col0, #T_be53a_row3_col1, #T_be53a_row3_col2, #T_be53a_row3_col3, #T_be53a_row3_col4, #T_be53a_row3_col5, #T_be53a_row3_col6, #T_be53a_row4_col0, #T_be53a_row4_col1, #T_be53a_row4_col2, #T_be53a_row4_col3, #T_be53a_row4_col4, #T_be53a_row4_col5, #T_be53a_row4_col6, #T_be53a_row5_col0, #T_be53a_row5_col1, #T_be53a_row5_col2, #T_be53a_row5_col3, #T_be53a_row5_col4, #T_be53a_row5_col5, #T_be53a_row5_col6, #T_be53a_row6_col0, #T_be53a_row6_col1, #T_be53a_row6_col2, #T_be53a_row6_col3, #T_be53a_row6_col4, #T_be53a_row6_col5, #T_be53a_row6_col6, #T_be53a_row7_col0, #T_be53a_row7_col1, #T_be53a_row7_col2, #T_be53a_row7_col3, #T_be53a_row7_col4, #T_be53a_row7_col5, #T_be53a_row7_col6, #T_be53a_row8_col0, #T_be53a_row8_col1, #T_be53a_row8_col2, #T_be53a_row8_col3, #T_be53a_row8_col4, #T_be53a_row8_col5, #T_be53a_row8_col6, #T_be53a_row9_col0, #T_be53a_row9_col1, #T_be53a_row9_col2, #T_be53a_row9_col3, #T_be53a_row9_col4, #T_be53a_row9_col5, #T_be53a_row9_col6, #T_be53a_row10_col0, #T_be53a_row10_col1, #T_be53a_row10_col2, #T_be53a_row10_col3, #T_be53a_row10_col4, #T_be53a_row10_col5, #T_be53a_row10_col6, #T_be53a_row11_col0, #T_be53a_row11_col1, #T_be53a_row11_col2, #T_be53a_row11_col3, #T_be53a_row11_col4, #T_be53a_row11_col5, #T_be53a_row11_col6, #T_be53a_row12_col0, #T_be53a_row12_col1, #T_be53a_row12_col2, #T_be53a_row12_col3, #T_be53a_row12_col4, #T_be53a_row12_col5, #T_be53a_row12_col6, #T_be53a_row13_col0, #T_be53a_row13_col1, #T_be53a_row13_col2, #T_be53a_row13_col3, #T_be53a_row13_col4, #T_be53a_row13_col5, #T_be53a_row13_col6, #T_be53a_row14_col0, #T_be53a_row14_col1, #T_be53a_row14_col2, #T_be53a_row14_col3, #T_be53a_row14_col4, #T_be53a_row14_col5, #T_be53a_row14_col6, #T_be53a_row15_col0, #T_be53a_row15_col1, #T_be53a_row15_col2, #T_be53a_row15_col3, #T_be53a_row15_col4, #T_be53a_row15_col5, #T_be53a_row15_col6, #T_be53a_row16_col0, #T_be53a_row16_col1, #T_be53a_row16_col2, #T_be53a_row16_col3, #T_be53a_row16_col4, #T_be53a_row16_col5, #T_be53a_row16_col6, #T_be53a_row17_col0, #T_be53a_row17_col1, #T_be53a_row17_col2, #T_be53a_row17_col3, #T_be53a_row17_col4, #T_be53a_row17_col5, #T_be53a_row17_col6 {
#   text-align: left;
# }
# #T_be53a_row0_col1, #T_be53a_row0_col2, #T_be53a_row0_col3, #T_be53a_row0_col4, #T_be53a_row0_col5, #T_be53a_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_be53a_row0_col7, #T_be53a_row1_col7, #T_be53a_row2_col7, #T_be53a_row3_col7, #T_be53a_row4_col7, #T_be53a_row5_col7, #T_be53a_row7_col7, #T_be53a_row8_col7, #T_be53a_row9_col7, #T_be53a_row10_col7, #T_be53a_row11_col7, #T_be53a_row13_col7, #T_be53a_row14_col7, #T_be53a_row15_col7, #T_be53a_row16_col7, #T_be53a_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_be53a_row6_col7, #T_be53a_row12_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_be53a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be53a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_be53a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_be53a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_be53a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_be53a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_be53a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_be53a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_be53a_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be53a_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_be53a_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_be53a_row0_col1" class="data row0 col1" >0.1416</td>
#       <td id="T_be53a_row0_col2" class="data row0 col2" >0.0814</td>
#       <td id="T_be53a_row0_col3" class="data row0 col3" >0.2148</td>
#       <td id="T_be53a_row0_col4" class="data row0 col4" >0.5380</td>
#       <td id="T_be53a_row0_col5" class="data row0 col5" >0.0431</td>
#       <td id="T_be53a_row0_col6" class="data row0 col6" >0.0360</td>
#       <td id="T_be53a_row0_col7" class="data row0 col7" >0.0520</td>
#     </tr>
#     <tr>
#       <th id="T_be53a_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_be53a_row1_col0" class="data row1 col0" >AdaBoost Regressor</td>
#       <td id="T_be53a_row1_col1" class="data row1 col1" >0.1820</td>
#       <td id="T_be53a_row1_col2" class="data row1 col2" >0.0976</td>
#       <td id="T_be53a_row1_col3" class="data row1 col3" >0.2522</td>
#       <td id="T_be53a_row1_col4" class="data row1 col4" >0.3932</td>
#       <td id="T_be53a_row1_col5" class="data row1 col5" >0.0513</td>
#       <td id="T_be53a_row1_col6" class="data row1 col6" >0.0468</td>
#       <td id="T_be53a_row1_col7" class="data row1 col7" >0.0330</td>
#     </tr>
#     <tr>
#       <th id="T_be53a_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_be53a_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_be53a_row2_col1" class="data row2 col1" >0.1857</td>
#       <td id="T_be53a_row2_col2" class="data row2 col2" >0.0856</td>
#       <td id="T_be53a_row2_col3" class="data row2 col3" >0.2542</td>
#       <td id="T_be53a_row2_col4" class="data row2 col4" >0.3696</td>
#       <td id="T_be53a_row2_col5" class="data row2 col5" >0.0524</td>
#       <td id="T_be53a_row2_col6" class="data row2 col6" >0.0490</td>
#       <td id="T_be53a_row2_col7" class="data row2 col7" >0.0630</td>
#     </tr>
#     <tr>
#       <th id="T_be53a_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_be53a_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_be53a_row3_col1" class="data row3 col1" >0.1814</td>
#       <td id="T_be53a_row3_col2" class="data row3 col2" >0.0981</td>
#       <td id="T_be53a_row3_col3" class="data row3 col3" >0.2646</td>
#       <td id="T_be53a_row3_col4" class="data row3 col4" >0.3010</td>
#       <td id="T_be53a_row3_col5" class="data row3 col5" >0.0543</td>
#       <td id="T_be53a_row3_col6" class="data row3 col6" >0.0471</td>
#       <td id="T_be53a_row3_col7" class="data row3 col7" >0.0300</td>
#     </tr>
#     <tr>
#       <th id="T_be53a_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_be53a_row4_col0" class="data row4 col0" >K Neighbors Regressor</td>
#       <td id="T_be53a_row4_col1" class="data row4 col1" >0.2162</td>
#       <td id="T_be53a_row4_col2" class="data row4 col2" >0.0924</td>
#       <td id="T_be53a_row4_col3" class="data row4 col3" >0.2779</td>
#       <td id="T_be53a_row4_col4" class="data row4 col4" >0.1710</td>
#       <td id="T_be53a_row4_col5" class="data row4 col5" >0.0572</td>
#       <td id="T_be53a_row4_col6" class="data row4 col6" >0.0573</td>
#       <td id="T_be53a_row4_col7" class="data row4 col7" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_be53a_level0_row5" class="row_heading level0 row5" >omp</th>
#       <td id="T_be53a_row5_col0" class="data row5 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_be53a_row5_col1" class="data row5 col1" >0.2288</td>
#       <td id="T_be53a_row5_col2" class="data row5 col2" >0.0932</td>
#       <td id="T_be53a_row5_col3" class="data row5 col3" >0.2917</td>
#       <td id="T_be53a_row5_col4" class="data row5 col4" >0.0502</td>
#       <td id="T_be53a_row5_col5" class="data row5 col5" >0.0602</td>
#       <td id="T_be53a_row5_col6" class="data row5 col6" >0.0614</td>
#       <td id="T_be53a_row5_col7" class="data row5 col7" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_be53a_level0_row6" class

# %%
print(best)
# Out:
# ExtraTreesRegressor(n_jobs=-1, random_state=4386)

# %% [markdown]
# XXXXXXX
#
# The best model is determined to be a Gradient Boosting Regressor.  The Gradient Boosting Regressor is an "ensemble learning algorithm that combines multiple weak learners to create a stronger model. It works by iteratively adding weak learners to the model, where each weak learner is trained to correct the mistakes made by the previous weak learners. The objective of the algorithm is to minimize the loss function, which is defined as the difference between the actual values and the predicted values." (https://medium.com/the-modern-scientist/gradient-boosting-regressor-the-best-machine-learning-algorithm-370b7b41ad09).  Now to evaluate the model to tell us the features of highest importance.
#
#
#
# The best model is determined to be a Random Forest Regressor.  This is a bagging method, not a boosted approach.  Each model is run independantly then the results are aggregated.  To learn more about what that is, check out https://python.plainenglish.io/random-forest-regression-model-d060706a5e7f.  Now to evaluate the model to tell us the features of highest importance.

# %%
plot_model(best, plot = 'feature_all')

# %% [markdown]
# This analysis highlights the top two features (P3 Feature 2, and P2 Feature 12) that were also amoung the highest on our correlation plot.  So in this investigation we will run some tests adjusting P3 Feature 2 and see how that affects our target.  Additional testing on the other highlighted features will also be done if its still necessary.
